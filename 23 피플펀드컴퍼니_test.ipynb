# %% [markdown]
# site : hackerrank

# %%
def getMaxProfit(pnl, k):
    # Write your code here
    temp = sum(pnl[:k])
    answer = temp
    print(pnl[:k])
    print(answer)
    i = 0
    
    while k+i+1 <= len(pnl):
        temp = temp-pnl[i]+pnl[k+i]
        answer = max(answer, temp)
        print(pnl[i+1:k+i+1])
        print(answer, sum(pnl[i+1:k+i+1]))
        i += 1
        
    return answer

# %%
def getMaxProfit(pnl, k):
    # Write your code here
    temp = 0
    answer = 0
    _k = 1
    i = 0
    
    while k+i+1 <= len(pnl):
        temp = temp-pnl[i]+pnl[k+i]
        answer = max(answer, temp)
        i += 1
        
    return answer

# %%
def getMaxProfit(pnl, k):
    # Write your code here
    answer = 0
    
    for j in range(1,k+1):
        i = 0
        temp = sum(pnl[:j])

        while j+i+1 <= len(pnl):
            print(pnl[i:j+i])
            temp = temp-pnl[i]+pnl[j+i]
            answer = max(answer, temp, 0)
            i += 1
        
    return answer

# %%
pnl = [4,3,-2,9,-4,2,7]
k = 6

getMaxProfit(pnl, k)
# Out:
# [4]
# [3]
# [-2]
# [9]
# [-4]
# [2]
# [4, 3]
# [3, -2]
# [-2, 9]
# [9, -4]
# [-4, 2]
# [4, 3, -2]
# [3, -2, 9]
# [-2, 9, -4]
# [9, -4, 2]
# [4, 3, -2, 9]
# [3, -2, 9, -4]
# [-2, 9, -4, 2]
# [4, 3, -2, 9, -4]
# [3, -2, 9, -4, 2]
# [4, 3, -2, 9, -4, 2]
# 15

# %%
pnl = [2,5,-7,8,-6,4,1,-9]
k = 5

getMaxProfit(pnl, k)
# Out:
# [2]
# [5]
# [-7]
# [8]
# [-6]
# [4]
# [1]
# [2, 5]
# [5, -7]
# [-7, 8]
# [8, -6]
# [-6, 4]
# [4, 1]
# [2, 5, -7]
# [5, -7, 8]
# [-7, 8, -6]
# [8, -6, 4]
# [-6, 4, 1]
# [2, 5, -7, 8]
# [5, -7, 8, -6]
# [-7, 8, -6, 4]
# [8, -6, 4, 1]
# [2, 5, -7, 8, -6]
# [5, -7, 8, -6, 4]
# [-7, 8, -6, 4, 1]
# 8

# %%
pnl = [2,5,-7,8,-6,4,1,-9]
k = 5
# result = 8

getMaxProfit(pnl, k)
# Out:
# [2]
# [5]
# [-7]
# [8]
# [-6]
# [4]
# [1]
# [2, 5]
# [5, -7]
# [-7, 8]
# [8, -6]
# [-6, 4]
# [4, 1]
# [2, 5, -7]
# [5, -7, 8]
# [-7, 8, -6]
# [8, -6, 4]
# [-6, 4, 1]
# [2, 5, -7, 8]
# [5, -7, 8, -6]
# [-7, 8, -6, 4]
# [8, -6, 4, 1]
# [2, 5, -7, 8, -6]
# [5, -7, 8, -6, 4]
# [-7, 8, -6, 4, 1]
# 8

# %% [markdown]
# ![image.png](attachment:a48367e9-caf3-4fe6-97c9-c08a370d1386.png)

# %% [markdown]
# ![image.png](attachment:b2a81b83-d6bf-46c3-ba24-b20f6b81d305.png)

# %% [markdown]
# ![image.png](attachment:272b8d33-072c-46b6-8d25-a8a0dc031e31.png)
